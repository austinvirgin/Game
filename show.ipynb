# %%
from gymnasium import spaces

self.observation_space = spaces.Box(
    low=np.array([0, 0, -10, -10, 0, 0], dtype=np.float32),
    high=np.array([self.width, self.height, 10, 10, self.height, self.height], dtype=np.float32),
    dtype=np.float32
)
